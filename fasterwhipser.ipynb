# %%
# !pip install git+https://github.com/Softcatala/whisper-ctranslate2
# Out:
# ...
#   Cloning https://github.com/Softcatala/whisper-ctranslate2 to /tmp/pip-req-build-ko9tlbv8
#   Running command git clone --filter=blob:none --quiet https://github.com/Softcatala/whisper-ctranslate2 /tmp/pip-req-build-ko9tlbv8
#   Resolved https://github.com/Softcatala/whisper-ctranslate2 to commit ebd0926c20a0f0e96c1e4e947ba1f617ed7e3f10
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 28.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.0/31.0 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 110.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.5 MB/s eta 0:00:00
# ...

# %%
# !apt install libcublas11
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcublaslt11
# The following NEW packages will be installed:
#   libcublas11 libcublaslt11
# 0 upgraded, 2 newly installed, 0 to remove and 32 not upgraded.
# Need to get 226 MB of archives.
# After this operation, 498 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublaslt11 amd64 11.7.4.6~11.5.1-1ubuntu1 [148 MB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 libcublas11 amd64 11.7.4.6~11.5.1-1ubuntu1 [78.2 MB]
# Fetched 226 MB in 3s (89.9 MB/s)
# Selecting previously unselected package libcublaslt11:amd64.
# (Reading database ... 121730 files and directories currently installed.)
# Preparing to unpack .../libcublaslt11_11.7.4.6~11.5.1-1ubuntu1_amd64.deb ...
# Unpacking libcublaslt11:amd64 (11.7.4.6~11.5.1-1ubuntu1) ...
# ...

# %%
# !whisper-ctranslate2 output.aac --language Cantonese --model large-v2 --word_timestamps True --max_line_width 15 --initial_prompt "我在做Google SEO教學,我說的是粵語，有時會加少量英文,粵語的部份請轉為書面語，謝謝" --device cuda
# Out:
# Estimating duration from bitrate, this may be inaccurate
# Detected language 'Cantonese' with probability 1.000000
# [00:00.000 --> 00:08.920] 關於圖片的文字描述,我就拿了另一篇關於JavaScript是什麼程式語言的一篇文章來講解一下
# [00:08.920 --> 00:13.420] 我們可以先右擊inspect去開這一頁的原始碼
# [00:13.420 --> 00:17.220] 拉下去第一幅圖就是這篇文章的縮圖
# [00:17.220 --> 00:22.560] 你會見到在這個image tag後面我加了一個alt的attribute
# [00:22.560 --> 00:25.600] 這個就是圖片的文字描述
# [00:25.600 --> 00:31.680] 這裡的描述我就直接拿了這個title來作為這張圖片的描述
# [00:31.680 --> 00:39.860] 再拉低一點,我就用了這兩張圖片去示範了alert你好和alert date的結果
# [00:39.860 --> 00:48.040] 右擊看看它的描述,就寫回js顯示alert這個功能的例子,那就比較清楚了
# [00:48.040 --> 00:52.860] 下面這個JavaScript的圖標就寫回JavaScript的圖標
# [00:52.860 --> 00:58.160] 去告訴網頁搜尋器知道那一幅圖你想表達的是什麼意思
# [00:58.160 --> 01:01.720] 又或者直接描述那幅圖的內容
# Transcription results written to '/content' directory

# %%
# !whisper-ctranslate2 --help
